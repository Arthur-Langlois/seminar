# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from SyntheticControlMethods import Synth, DiffSynth
import datetime

# %%
df = pd.read_csv('../Data/US-Gun-Violence.csv')
df['incident_date'] = pd.to_datetime(df['incident_date'])
df['incident_date'] = pd.DatetimeIndex(df['incident_date']).year
df = df.drop(columns=["incident_id", 'city_or_county', 'address', 'injured'], axis=1)
df = df.sort_values(by=['state', 'incident_date'], ascending=True)
#combine and add all killed by year

df.groupby(['incident_date']).agg('sum')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/OscarEngelbrektson/SyntheticControlMethods/master/examples/datasets/german_reunification.csv')   
df = df.drop(columns="code", axis=1)
df.head(15)
# Out:
#    country  year   gdp    infrate      trade  schooling  invest60  invest70  \
# 0      USA  1960  2879        NaN   9.693181  43.799999       NaN       NaN
# 1      USA  1961  2929   1.075182   9.444655        NaN       NaN       NaN
# 2      USA  1962  3103   1.116071   9.429324        NaN       NaN       NaN
# 3      USA  1963  3227   1.214128   9.470706        NaN       NaN       NaN
# 4      USA  1964  3420   1.308615   9.725879        NaN       NaN       NaN
# 5      USA  1965  3667   1.668461   9.730347  43.799999       NaN       NaN
# 6      USA  1966  3974   2.991000  10.097592        NaN       NaN       NaN
# 7      USA  1967  4154   2.775636  10.208102        NaN       NaN       NaN
# 8      USA  1968  4494   4.217721  10.593937        NaN       NaN       NaN
# 9      USA  1969  4805   5.414701  10.635633        NaN       NaN       NaN
# 10     USA  1970  4999   5.895296  11.388641  44.400002       NaN       NaN
# 11     USA  1971  5362   4.255929  11.367576        NaN       NaN       NaN
# 12     USA  1972  5838   3.305615  11.967158        NaN       NaN       NaN
# 13     USA  1973  6464   6.220064  13.713565        NaN       NaN       NaN
# 14     USA  1974  6951  11.035260  17.316135        NaN       NaN       NaN
#
#     invest80   industry
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# 5        NaN        NaN
# 6        NaN        NaN
# 7        NaN        NaN
# 8        NaN        NaN
# 9        NaN        NaN
# 10       NaN        NaN
# 11       NaN  34.508629
# 12       NaN  34.444290
# 13       NaN  34.375210
# 14       NaN  34.036060

# %%
#Fit classic Synthetic Control
# must downgrade to scipy==1.4.1 but it will not work with python 3.9
sc = Synth(df, "gdp", "country", "year", 1990, "West Germany", pen=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <module>
#       1 #Fit classic Synthetic Control
#       2 # must downgrade to scipy==1.4.1 but it will not work with python 3.9
# ----> 3 sc = Synth(df, "gdp", "country", "year", 1990, "West Germany", pen=0)
#
# File /usr/local/lib/python3.9/site-packages/SyntheticControlMethods/main.py:340, in Synth.__init__(self, dataset, outcome_var, id_var, time_var, treatment_period, treated_unit, n_optim, pen, exclude_columns, random_seed, **kwargs)
#     337 self.original_data = SynthBase(**original_checked_input)
#     339 #Get synthetic Control
# --> 340 self.optimize(self.original_data.treated_outcome, self.original_data.treated_covariates,
#     341             self.original_data.control_outcome, self.original_data.control_covariates,
#     342             self.original_data.pairwise_difference,
#     343             self.original_data, False, pen, n_optim)
#     345 #Compute rmspe_df
#     346 self._pre_post_rmspe_ratios(None, False)
#
# File /usr/local/lib/python3.9/site-packages/SyntheticControlMethods/optimize.py:103, in Optimize.optimize(self, treated_outcome, treated_covariates, control_outcome, control_covariates, pairwise_difference, data, placebo, pen, steps, verbose)
#     100     bnds = tuple((0,20) if ((pen=="auto") and (x==data.n_covariates)) else (0,1) for x in range(data.n_covariates + 1))
#     102 #Optimze
# --> 103 res = minimize(self.total_loss, v_0,  args=(args),
#     104                 method='L-BFGS-B', bounds=bnds,
#     105                 options={'gtol': 1e-8,'disp':3, 'iprint':3})
#     107 if verbose:
#     108     print("Successful:", res.success)
#
# File /usr/local/lib/python3.9/site-packages/scipy/optimize/_minimize.py:623, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     620     return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     621                               **options)
#     622 elif meth == 'l-bfgs-b':
# --> 623     return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     624                             callback=callback, **options)
#     625 elif meth == 'tnc':
#     626     return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     627                          **options)
#
# File /usr/local/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py:306, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     303     else:
#     304         iprint = disp
# --> 306 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     307                               bounds=new_bounds,
#     308                               finite_diff_rel_step=finite_diff_rel_step)
#     310 func_and_grad = sf.fun_and_grad
#     312 fortran_int = _lbfgsb.types.intvar.dtype
#
# File /usr/local/lib/python3.9/site-packages/scipy/optimize/optimize.py:261, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     257     bounds = (-np.inf, np.inf)
#     259 # ScalarFunction caches. Reuse of fun(x) during grad
#     260 # calculation reduces overall function evaluations.
# --> 261 sf = ScalarFunction(fun, x0, args, grad, hess,
#     262                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     264 return sf
#
# File /usr/local/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:159, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     155         self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     156                                    **finite_diff_options)
#     158 self._update_grad_impl = update_grad
# --> 159 self._update_grad()
#     161 # Hessian Evaluation
#     162 if callable(hess):
#
# File /usr/local/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:238, in ScalarFunction._update_grad(self)
#     236 def _update_grad(self):
#     237     if not self.g_updated:
# --> 238         self._update_grad_impl()
#     239         self.g_updated = True
#
# File /usr/local/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_grad()
#     153 self._update_fun()
#     154 self.ngev += 1
# --> 155 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     156                            **finite_diff_options)
#
# File /usr/local/lib/python3.9/site-packages/scipy/optimize/_numdiff.py:448, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     446     f0 = np.atleast_1d(f0)
#     447     if f0.ndim > 1:
# --> 448         raise ValueError("`f0` passed has more than 1 dimension.")
#     450 if np.any((x0 < lb) | (x0 > ub)):
#     451     raise ValueError("`x0` violates bound constraints.")
#
# ValueError: `f0` passed has more than 1 dimension.

# %%
#Visualize synthetic control
sc.plot(["original", "pointwise", "cumulative"], treated_label="West Germany", 
            synth_label="Synthetic West Germany", treatment_label="German Reunification")
